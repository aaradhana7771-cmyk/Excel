# %% [markdown]
# #**Question**
# 1.Create a unique mapping of courseID and category,and use it to populate the category column for the dataset using an appropriate lookup function.
#
# ![Screenshot 2026-07-28 153808.png](data:image/png;base64,...)

# %% [markdown]
# After completing this determine which Category Has The Highest number of enrollment

# %% [markdown]
#   Answer-1 https://1drv.ms/x/c/5981540a5e411f1c/IQBE5kkCyihgR7uHQFP03FuyAQcQ7LzA1sIP-JKQ6IkgsR4?e=goRWP1

# %% [markdown]
# Ouestion-2 Calculate the total number of enrollments Made through the mobile platform
#        Answer-> https://1drv.ms/x/c/5981540a5e411f1c/IQBn_BHW02hITb3gqKlKSSkYAdQ0hnTKMMIi6WT3OXpXyyM?e=2mh6xk

# %% [markdown]
# Question-3  Find the total Payment Amount Genrated From The Data Analytics Course.
#        Answer-https://1drv.ms/x/c/5981540a5e411f1c/IQBI-PFIV1YQRYzfKcSk93s1AcvnieiK1IaBR5SPgizB8do?e=7luPWQ

# %% [markdown]
# Queation-4 Create a Dynamic lookup Where entering a StudentID return the corresponding MentorName
#      Answer- https://1drv.ms/x/c/5981540a5e411f1c/IQBnAUITXEqbQ5a7qmOnVFOsAdY8o4bpJ9dS3mOvsvp-Hw8?e=DHebv8

# %% [markdown]
# Question-5 Create a new Column perfomance Status:
#
#
#         -"Target Achieved" if PaymentAmount >_ TargetRevenue
#         -"Below Target" otherwise
#         Also Calculate The percentage Of records Where the Target is achived.

# %% [markdown]
#   Answer-5 https://1drv.ms/x/c/5981540a5e411f1c/IQBnVBEQ_rauTbHveSEc4sGUAYHxeG-XMIITM8i172mkyCA?e=uHgGgE

# %% [markdown]
# Question-6 Validate The Discountpercent Values in the dataset using Discountcode.
#
#  Create a new Column New_Discountpercent Such That:

# %%
  If Discount Code is Blankor Invalid- return 0
  Otherwise- retain the existing Discountpercent value

# %% [markdown]
#   Answer-https://1drv.ms/x/c/5981540a5e411f1c/IQBUWCsfWBOLSJauJMG1wvImAUbcrFHV6wwuMXTqopSyMZY?e=sYEtSM

# %% [markdown]
# Question-7 Create a Dynamic Lookup Where entering a StudentName Return the corresponding Platform using INDEX and MATCH funtions only.
# do not use VLOOkUP or XLOOKUP.
#
#    Answer- https://1drv.ms/x/c/5981540a5e411f1c/IQBnC6UWdSQpRZbh5bBebIB5Acmdbb4H4UtqsDspqjzawt8?e=lJjK8J

# %% [markdown]
# Question-8 Calculate Total Net Revenue After Discount for all records using a single Formula. Also Compare Total revenue before and after discount.
#
#   Answer- https://1drv.ms/x/c/5981540a5e411f1c/IQC1eu0bAq6aRK1sbVSN2rD8AWcouLCeY7Ss363Dd7gc72g?e=oGPGUJ

# %% [markdown]
# Question-9 Count the number of records Where:
#
#    Category = Analytics
#
#   Platform = Web
#
#    Answer-9 https://1drv.ms/x/c/5981540a5e411f1c/IQBWbxz3slOVSYQFESGR1oy_AcEOu6DHpF62DGDyWDyF6w0?e=P4Fqqy

# %% [markdown]
# Question-10 Create a Dynamic lookup where entering a StudentID return the entirevrow of details (StudentName,CourseID,Coursename,Batch,MentorName,Platform,paymentAmount ,Discount) using Single formula.
#
#   Answer-10 https://1drv.ms/x/c/5981540a5e411f1c/IQAC16QzcnjJRY8AlgGVdTSfAcOmq6s7Qp-LoDqHYpO3idc?e=d1rjRf

# %% [markdown]
#  Question-11 Create a pivot Table to Analyze total payment Amount across:
#
#     Category(Rows)
#
#     Platform(column)

# %% [markdown]
#  Answer-https://1drv.ms/x/c/5981540a5e411f1c/IQBdy9JFqQuRRqujWmyNGQs-AXoPf0wnMLTJD5p56kjsY0c?e=sy2Jp4

# %% [markdown]
# Question-12 Create a calculated field in the pivot table to compute net revenue using the formula:
#
# NET REVENUE = payment amount *(1-discount%)
#
# Compare the results with total revnue and observe any inconsistensi (if present)
#
# Answer https://1drv.ms/x/c/5981540a5e411f1c/IQCS9y0q4MW3T7wFNtzmINazAQS2hOZLuygkYnHgU3kw2SQ?e=pRDXnI

# %% [markdown]
# Question-13 Create an interactive dashboard that includes;
#
#             Slicers for category, mentor name, and platform
#
#             A column/bar chart showing revenue by course
#
#             A line chart showing revenue trend over paymentdate
#
#             KPIs:
#
#                  Total revenue
#                  Average payment
#                  % Target Achieved

# %% [markdown]
# Answer-13 https://1drv.ms/x/c/5981540a5e411f1c/IQCmpOmKSlSIR6mqKVjAykc3AYJGjdUTEujKNyr86nAuIDI?e=bIQiTb

# %% [markdown]
# https://1drv.ms/x/c/5981540a5e411f1c/IQAMApytqcBGTrIj2dCagxZvAVAoyJ11oVgij4mCxom15sM?e=BebYtR

# %% [markdown]
# Question-14 Based on Your Dashboard and analysis identity the top performing combination of category and platform in term of revenue
#
# provide:
#
#        The Category
#        The platform
#        The revenue generated

# %% [markdown]
#   Answer-https://1drv.ms/x/c/5981540a5e411f1c/IQAKZOWLgG2RToSy-kz03t2aAVWclGhL9QSu0co42_9D5W8?e=nebKVk

# %% [markdown]
# After Complting this Determine which Category has
